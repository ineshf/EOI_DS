# %% [markdown]
# # **INTRO PANDAS EJERCICIOS**

# %% [markdown]
# ### **Ejercicio 1**

# %% [markdown]
# Crear una serie de Pandas con 10 elementos inicialmente con el valor 0 y modifica el primer, segundo, cuarto y séptimo elemento con los valores 1, 2, 4 y 7 respectivamente.

# %% [markdown]
# ### **Ejercicio 2**

# %% [markdown]
# Crear un dataframe con los siguientes valores:
#
# Id Nombre Edad Nacionalidad
#
# 22 Juan   32   España
#
#  1 John   45   EEUU
#
# 13 Franz  38   Alemania
#
# 44 Vito   65   Italia

# %% [markdown]
# ### **Ejercicio 3**

# %% [markdown]
# Copia en una variable de Pandas el fichero dataset.csv y obten el número de filas y columnas

# %% [markdown]
# ### **Ejercicio 4**

# %% [markdown]
# Obtener el mínimo, el máximo y el valor medio de los Puntos del dataframe y obtener el porcentaje total de registros de Madrid en el dataset.

# %% [markdown]
# ### **Ejercicio 5**

# %% [markdown]
# Obtener los 7 primeros registros del dataset apareciendo únicamente las columnas *Id*, *Nombre* y *Apellido*

# %% [markdown]
# ### **Ejercicio 6**

# %% [markdown]
# Obtener los 5 últimos registros del dataset apareciendo únicamente las columnas *Id*, *Nombre* y *Puntos*

# %% [markdown]
# Para seleccionar columnas completas de un dataframe podemos utilizar la notación con corchetes y el nombre del campo o de los campos

# %% [markdown]
# ### **Ejercicio 7**

# %% [markdown]
# Selecciona todos los registros del dataframe que tengan un *Id* menor que 8 y *Puntos* 7 o menos.

# %% [markdown]
# ### **Ejercicio 8**

# %% [markdown]
# Selecciona todos los registros del dataframe que tengan un *Fecha* mayor a 1989-12-31 o que sean de *Ciudad* Barcelona.

# %% [markdown]
# ### **Ejercicio 9**

# %% [markdown]
# Ordena los 6 primeros registros del dataframe por *Apellidos* y ordena en segundo lugar por *Nombre*.

# %% [markdown]
# ### **Ejercicio 10**

# %% [markdown]
# Agrupa por *Ciudad* el número máximo de *Puntos* asociados esa ciudad.

# %% [markdown]
# Agrupa por *Pais* el número medio de *Puntos* asociados ese pais.
